# %% [markdown]
# # SVM
# *   https://www.youtube.com/watch?v=_YPScrckx28
# *   https://en.wikipedia.org/wiki/Support_vector_machine
# *   https://scikit-learn.org/1.5/modules/svm.html

# %% [markdown]
# Metoda: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#examples-using-sklearn-model-selection-gridsearchcv

# %% [markdown]
# Dane do analizy: https://www.kaggle.com/datasets/raminhuseyn/hr-analytics-data-set

# %% [markdown]
# Zadanie: zaczytać dane i zbudować model: tree, random forest, logistic, kNN

# %%
# !kaggle datasets download -d raminhuseyn/hr-analytics-data-set
# Out:
# Dataset URL: https://www.kaggle.com/datasets/raminhuseyn/hr-analytics-data-set
# License(s): other
# hr-analytics-data-set.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip hr-analytics-data-set.zip
# Out:
# Archive:  hr-analytics-data-set.zip
# replace HR_capstone_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: HR_capstone_dataset.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('HR_capstone_dataset.csv')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df['left'].mean()
# Out:
# 0.2380825388359224

# %%
df['left'].value_counts()
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %%
df_dummy = pd.get_dummies(df, drop_first=True)
df_dummy
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
from sklearn.model_selection import train_test_split

X = df_dummy.drop(columns=['left'], axis=1)
y = df_dummy['left']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# ## Zadanie: zbudować model korzystając z SVM oraz grid search

# %%
from sklearn import svm

# %%
from sklearn.model_selection import GridSearchCV

# %%
svc = svm.SVC(random_state=0, )

# %%
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
svc = svm.SVC(random_state=0)
clf = GridSearchCV(svc, parameters)
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(random_state=0),
#              param_grid={'C': [1, 10], 'kernel': ('linear', 'rbf')})

# %%
clf.best_paramms_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
clf_sel = clf.best_estimator_

# %%
svc = svm.SVC(C=10, kernel='rbf')  #  clf_sel
svc.fit(X_train, y_train)
# Out:
# SVC(C=10)

# %%
print(classification_report(y_test, svc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      3462
#            1       0.90      0.92      0.91      1038
#
#     accuracy                           0.96      4500
#    macro avg       0.94      0.94      0.94      4500
# weighted avg       0.96      0.96      0.96      4500

# %%
print(classification_report(y_train, svc.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      7966
#            1       0.94      0.93      0.94      2533
#
#     accuracy                           0.97     10499
#    macro avg       0.96      0.96      0.96     10499
# weighted avg       0.97      0.97      0.97     10499
